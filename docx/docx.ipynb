# %%
import pandas as pd
from docx.api import Document
from pprint import pprint
import requests
from bs4 import BeautifulSoup
import json

# %%
document = Document(r'd_list\files\table\1 Список Нефтянка.docx')
# document = Document(r'd_list\files\table\Ассоциации Казахстана.docx')
table = document.tables[0]

data = []
for i, row in enumerate(table.rows[1:]):
    text = (cell.text for cell in row.cells)
    print()
    # if i == 10:
    #     break
    
    data.append(list(text)[1:])
pprint(data)
# Out:
# [['АО "НК "КазМунайГаз"\n'
#   '\n'
#   'Алиби Нуржан Коштайулы\n'
#   'Сектор\xa0надежности оборудования\n'
#   'АО НК «КазМунайГаз»\n'
#   'Главный специалист\n'
#   'Раб. тел: 8 (7172) 78-62-55\n'
#   'e-mail:\xa0Alibi@kmg.kz\n',
#   'astana@kmg.kz\nd.zhanaspayeva@kmg.kz\ne.zhampeisov@kmg.kz'],
#  ['Актобе нефтепереработка', 'info@aktoberefinery.kz'],
#  ['Союз нефтесервисных компаний Казахстана', 'info@kazservice.kz'],
#  ['Asia Gas Pipeline', 'agp@agp.com.kz'],
#  ['КазТрансГаз', 'info@kaztransgas.kz'],
#  ['КазТрансОйл\n'
#   'Ташметов Болат Алмасович\n'
#   'Ведущий инженер департамента управления проектами АО «КазТрансОйл»\n'
#   'вебсайт:\xa0www.kaztransoil.kz\n'
#   'раб. тел. +7 7172 55-53-21\n'
#   'г.Астана, ул. Туран 20,\n',
#   'office@kaztransoil.kz\n'],
#  ['Интергаз Центральная Азия', 'info@ica.kz\n'],
#  ['Казахский Институт Нефти и Газа', 'info@king.kz'],
#  ['Информационно-аналитический центр нефти и газа', 'reception@iacng.kz'],
# ...

# %%
len(data)
# Out:
# 64

# %%
headers = {
  'Accept': 'application/json, text/plain, */*',
  'Accept-Language': 'en-US,en;q=0.9',
  'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....MIgO8oU_vke8hfr1O6WB1TZcY0N1qwgXbL2ijbJeyAjSxePk5HCMGg0lI3PBh5GwjRymuh9DFb4NA9t_AA1UnnfSHYCAAabMzA2k02fs6CndlGL9EQ5HQrVlorl7opMimAS3Qz_jI_yvX_9g7_PcgD2nTzL52I017YpRkU1Si2OxXVxoBL9uuHtGoqXHmK4YUdlUx_xFkxL9O-2tpWnySVrGC5U4kEXEbWuwxUXFgZ41RxJ0GP69cRIUpj00C8M8GUDDgzDbQ7PAp0uehEYm1boTDhUveRGI7zrTHjIbh--mXa8cZWBeQIJlg2TKure_oC9WIX2AWvJb62Ksom6eJg',
  'Connection': 'keep-alive',
  'Content-Type': 'application/json',
  'Cookie': 'g_state={"i_l":0}; sessionid=22iydkx9141yylq6m0o36rxtso74v1ab',
  'Origin': 'https://kompra.kz',
  'Referer': 'https://kompra.kz/search?q=%D0%90%D0%BA%D1%82%D0%BE%D0%B1%D0%B5%20%D0%BD%D0%B5%D1%84%D1%82%D0%B5%D0%BF%D0%B5%D1%80%D0%B5%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0&c=KZ&t=UL',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-origin',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
  'r': 'a016azBNVGs0TkRBM016TTRNalk0YQ==',
  'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

url = "https://kompra.kz/api/search/company?size=20"
base_url = "https://kompra.kz/open-company/{}"
all_data = []

for d in data:
    # row = {}
    try:
        query = d[0].split('\n')[0]
        print(query)
    
        payload = json.dumps({
          "code": "KZ",
          "filter": {
            "name": query
          }
        })
        
    
        res = requests.post(url, headers=headers, data=payload)
    
        res_data = res.json()['content'][0]
        # pprint(res_data)
        id = res_data['id']
        print(id)
        
    
        res = requests.get(base_url.format(id)).json()
        all_data.append(res)
    except Exception as e:
        print(e)
        print(d)
    # row['id'] = res['id']
    # row['bin'] = res['bin']
    # row['city'] = res['city']
    # row['field'] = res['field']
    # row['address law'] = res['lawAddress']
    # row['registered_on'] = res[''
print(len(all_data))
# Out:
# АО "НК "КазМунайГаз"
# 219314746
# Актобе нефтепереработка
# 1492856
# Союз нефтесервисных компаний Казахстана
# 1551357
# Asia Gas Pipeline
# 11858510
# КазТрансГаз
# 1688446
# КазТрансОйл
# 1391525
# Интергаз Центральная Азия
# 1471949
# Казахский Институт Нефти и Газа
# 1419593
# Информационно-аналитический центр нефти и газа
# 1485827
# АО «Конденсат»
# 1376979
# ТОО «КМГ Инжиниринг»
# 1618331
# ТОО «НИИ Каспиймунайгаз»
# 1677730
# НИПИнефтегаз
# list index out of range
# ['НИПИнефтегаз', 'info@kaznipi.kz']
# НОРТ КАСПИАН ОПЕРЕЙТИНГ КОМПАНИ
# 1702739
# Казахстанско-Китайский Трубопровод
# 1779719
# Карачаганак Петролиум Оперейтинг Б.В.
# 1501889
# ТОО «Газпром нефть-Казахстан»
# 1715869
# ТОО Тенгизшевройл
# 1674049
# АО КазТрансГаз Аймак
# 1406072
# АО «Эмбамунайгаз»
# 1716047
# ТОО "АтырауНефтеМаш"
# 1694858
# ТОО «Полимер Продакшн»
# 1715172
# ТОО «Жаикмунай»
# 1377370
# ТОО «Объединенная Химическая Компания»
# 264000239
# АО «Озенмунайгаз»
# 1496602
# ГАЗОIL
# 1523536
# ...

# %%
len(all_data)
# Out:
# 59

# %%
df = pd.DataFrame(data=all_data)

writer = pd.ExcelWriter(
    f"./Data 1 Список Нефтянка.xlsx",
    engine="xlsxwriter",
    engine_kwargs={"options": {"strings_to_urls": False}},
)

df.to_excel(writer, index=False, freeze_panes=(1, 1))
writer.close()
# df.to_csv(f"./{output_file}.csv", index=False)
